# %%
from ultralytics import YOLO
import cv2

VIDEO_PATH = "/content/input.mp4"
OUTPUT_PATH = "output_tracked.mp4"
MODEL_PATH = "yolov8n.pt"

model = YOLO(MODEL_PATH)
import os

print(os.listdir("/content"))

cap = cv2.VideoCapture(VIDEO_PATH)
if not cap.isOpened():
    raise ValueError("Cannot open input video")

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

fourcc = cv2.VideoWriter_fourcc(*"mp4v")
writer = cv2.VideoWriter(OUTPUT_PATH, fourcc, fps, (width, height))

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model.track(
        frame,
        persist=True,
        tracker="bytetrack.yaml",
        conf=0.25,
        iou=0.5,
        verbose=False
    )

    result = results[0]
    annotated_frame = result.plot()

    writer.write(annotated_frame)
    cv2.imshow("YOLOv8 Video Tracking", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
writer.release()
cv2.destroyAllWindows()

print(f"Saved tracked video to: {OUTPUT_PATH}")
# Out:
# ['.config', 'input.mp4', '.ipynb_checkpoints', 'yolov8n.pt', 'sample_data']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9069/4249201115.py in <cell line: 0>()
#      13 cap = cv2.VideoCapture(VIDEO_PATH)
#      14 if not cap.isOpened():
# ---> 15     raise ValueError("Cannot open input video")
#      16
#      17 width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#
# ValueError: Cannot open input video

# %%
import os

path = "/content/input.mp4"
print("exists:", os.path.exists(path))
print("size:", os.path.getsize(path) if os.path.exists(path) else "missing")
# Out:
# exists: True
# size: 1286043

# %%
# !apt-get update -qq
# !apt-get install -y ffmpeg -qq
# !ffmpeg -y -i /content/input.mp4 -c:v libx264 -preset fast -pix_fmt yuv420p /content/fixed.mp4
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
import cv2

cap = cv2.VideoCapture("/content/fixed.mp4")
print("opened:", cap.isOpened())

ret, frame = cap.read()
print("first frame read:", ret)
if ret:
    print("shape:", frame.shape)

cap.release()
# Out:
# opened: False
# first frame read: False

# %%
#deleting the file

import os

if os.path.exists("/content/input.mp4"):
    os.remove("/content/input.mp4")

print(os.listdir("/content"))
# Out:
# ['.config', '.ipynb_checkpoints', 'yolov8n.pt', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()
print(uploaded.keys())
# Out:
#      <input type="file" id="files-5ad01941-46e1-48a7-8cb0-1ebb47d8e1a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5ad01941-46e1-48a7-8cb0-1ebb47d8e1a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.4 MB/s eta 0:00:00
# ...
